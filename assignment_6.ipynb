# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os
# %matplotlib inline

# %%
path=os.getcwd()+'/weather.csv'
df=pd.read_csv(path)
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#1
plt.plot(df['Sunshine'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#2
plt.scatter(df['MinTemp'],df['MaxTemp'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#3
plt.hist(df['Humidity9am'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#4
sns.distplot(df['Humidity9am'])

# %%
#5
sns.kdeplot(df['Humidity3pm'])

# %%
#6
sns.kdeplot(df['Cloud3pm'],df['Cloud9am'])

# %%
#7
sns.jointplot(df['MinTemp'],df['MaxTemp'],kind='hex')

# %%
#8
sns.jointplot(df['Pressure9am'],df['Pressure3pm'],kind='kde')

# %%
#9
sns.lmplot(x='MinTemp',y='MaxTemp',data=df,hue='WindGustDir')

# %%
#10
sns.lmplot(x='MinTemp',y='MaxTemp',data=df,hue='WindGustDir',fit_reg=False)

# %%
#11
plt.figure(figsize=(10,8))
sns.stripplot(x='WindDir9am',y='WindSpeed9am',data=df)

# %%
#12
plt.figure(figsize=(10,8))
sns.swarmplot(x='WindDir9am',y='WindSpeed9am',data=df)

# %%
#13
plt.figure(figsize=(10,8))
sns.boxplot(x='WindDir3pm',y='WindSpeed3pm',data=df)

# %%
#14
plt.figure(figsize=(15,10))
sns.barplot(x='WindGustDir',y='WindGustSpeed',data=df)

# %%
#15
sns.countplot(x='RainToday',data=df)

# %%
#16
c=df.corr()
sns.heatmap(c)

# %%
#17
d=pd.Series((df.loc[:,'RainToday']))
y=0
n=0

for x in range (0,366):
    if d[x]=='Yes':
        y=y+1
    else:
        n=n+1
rain_label=['Yes','No']
rain_data=[y,n]
plt.pie(rain_data,labels=rain_label)
plt.title('Rain in a year')
plt.show()

# %%
#18
plt.bar(rain_label, rain_data)
plt.ylabel('No. of days')
plt.xticks(fontsize=15, rotation=30)
plt.title('Rain In a year')
plt.show
# Out:
# <function matplotlib.pyplot.show>
